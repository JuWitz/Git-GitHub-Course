# %% [markdown]
# Hey, this is a first markdown cell to capture initial text related to Git & GitHub blog post:
# https://blog.udacity.com/2015/06/a-beginners-git-github-tutorial.html

# %%
import pandas as pd
import numpy as np

x=[1, 2, 4, 6]
print(x)
# Out:
# [1, 2, 4, 6]

# %%
d={'col1':x, 'col2':x}
print(d)
y=pd.DataFrame(data=d)

y.plot()
# Out:
# {'col1': [1, 2, 4, 6], 'col2': [1, 2, 4, 6]}
